# %%
# langchain_text_splitters or 
# langchain.text_splitter


##   we have
## RecursiveCharacterTextSplitter 
## CharacterTextSplitter

# %%
## PDF document loader

from langchain_community.document_loaders import PyPDFLoader

pdf_loader = PyPDFLoader('/Users/balmukundmishra/Desktop/Learn-Fine-tune-deploy-LLM-Langchain/langchain/1.data-ingestion/Interview_questions.pdf')

pdf_data = pdf_loader.load()

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter =RecursiveCharacterTextSplitter(
    chunk_size =300,
    chunk_overlap = 20
)

#final_chunked_docuemnt = text_splitter.create_documents(pdf_data)
## above one (.create_docemnets is helpfull for text files)
final_chunked_docuemnt = text_splitter.split_documents(pdf_data)

# %%
final_chunked_docuemnt
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2025-01-13T21:21:11+05:30', 'author': 'Steve Nouri', 'moddate': '2025-01-13T21:21:11+05:30', 'source': '/Users/balmukundmishra/Desktop/Learn-Fine-tune-deploy-LLM-Langchain/langchain/1.data-ingestion/Interview_questions.pdf', 'total_pages': 54, 'page': 0, 'page_label': '1'}, page_content='Data Science Interview Questions \n \n \nStatistics: \n1. What is the Central Limit Theorem and why is it important? \n“Suppose that we are interested in estimating the average height among all people. Collecting data for'),
# ...

# %%
print(final_chunked_docuemnt[0])
# Out:
# page_content='Data Science Interview Questions
#
#
# Statistics:
# 1. What is the Central Limit Theorem and why is it important?
# “Suppose that we are interested in estimating the average height among all people. Collecting data for' metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2025-01-13T21:21:11+05:30', 'author': 'Steve Nouri', 'moddate': '2025-01-13T21:21:11+05:30', 'source': '/Users/balmukundmishra/Desktop/Learn-Fine-tune-deploy-LLM-Langchain/langchain/1.data-ingestion/Interview_questions.pdf', 'total_pages': 54, 'page': 0, 'page_label': '1'}

# %%
final_chunked_docuemnt[1]
# Out:
# Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2025-01-13T21:21:11+05:30', 'author': 'Steve Nouri', 'moddate': '2025-01-13T21:21:11+05:30', 'source': '/Users/balmukundmishra/Desktop/Learn-Fine-tune-deploy-LLM-Langchain/langchain/1.data-ingestion/Interview_questions.pdf', 'total_pages': 54, 'page': 0, 'page_label': '1'}, page_content='every person in the world is impossible. While we can’t obtain a height measurement from everyone in the \npopulation, we can still sample some people. The question now becomes, what can we say about the')

# %%
## langchain text loader
from langchain_community.document_loaders import TextLoader

data = TextLoader('/Users/balmukundmishra/Desktop/Learn-Fine-tune-deploy-LLM-Langchain/langchain/1.data-ingestion/data1.txt').load()
#text_document = data.load()

# %%
print(data[0])
# Out:
# page_content='Emotion recognition
#
# 6 languages
# Article
# Talk
# Read
# Edit
# View history
#
# Tools
# Appearance  hide
# Text
#
# Small
#
# Standard
#
# Large
# Width
#
# Standard
#
# Wide
# Color (beta)
#
# Automatic
#
# Light
#
# Dark
# From Wikipedia, the free encyclopedia
# Part of a series on
# Artificial intelligence (AI)
#
# hide
# Major goals
# Artificial general intelligence Intelligent agent Recursive self-improvement Planning Computer vision General game playing Knowledge representation Natural language processing Robotics AI safety
# show
# Approaches
# show
# Applications
# show
# Philosophy
# show
# History
# show
# Glossary
# vte
# ...

# %%
file_path = "/Users/balmukundmishra/Desktop/Learn-Fine-tune-deploy-LLM-Langchain/langchain/1.data-ingestion/data1.txt"

data  = ""
with open(file_path) as f:
    data = f.read()

data
# Out:
# 'Emotion recognition\n\n6 languages\nArticle\nTalk\nRead\nEdit\nView history\n\nTools\nAppearance  hide\nText\n\nSmall\n\nStandard\n\nLarge\nWidth\n\nStandard\n\nWide\nColor (beta)\n\nAutomatic\n\nLight\n\nDark\nFrom Wikipedia, the free encyclopedia\nPart of a series on\nArtificial intelligence (AI)\n\nhide\nMajor goals\nArtificial general intelligence Intelligent agent Recursive self-improvement Planning Computer vision General game playing Knowledge representation Natural language processing Robotics AI safety\nshow\nApproaches\nshow\nApplications\nshow\nPhilosophy\nshow\nHistory\nshow\nGlossary\nvte\nEmotion recognition is the process of identifying human emotion. People vary widely in their accuracy at recognizing the emotions of others. Use of technology to help people with emotion recognition is a relatively nascent research area. Generally, the technology works best if it uses multiple modalities in context. To date, the most work has been conducted on automating the recogniti
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter1 = RecursiveCharacterTextSplitter(chunk_size = 200, chunk_overlap = 20)

# %%
text_splitter1

# %%
text = text_splitter1.create_documents([data])

# %%
print(text[0])
# Out:
# page_content='Emotion recognition
#
# 6 languages
# Article
# Talk
# Read
# Edit
# View history
#
# Tools
# Appearance  hide
# Text
#
# Small
#
# Standard
#
# Large
# Width
#
# Standard
#
# Wide
# Color (beta)
#
# Automatic
#
# Light'

# %%
type(text[0])
# Out:
# langchain_core.documents.base.Document

# %%
## CharacterTextXplitter

## langchain text loader
from langchain_community.document_loaders import TextLoader

data = TextLoader('/Users/balmukundmishra/Desktop/Learn-Fine-tune-deploy-LLM-Langchain/langchain/1.data-ingestion/data1.txt').load()
#text_document = data.load()

# %%
from langchain.text_splitter import CharacterTextSplitter
text_splitR = CharacterTextSplitter(separator="\n\n", 
                                    chunk_size=100, chunk_overlap = 20)
chunked_data = text_splitR.split_documents(data)
# Out:
# Created a chunk of size 819, which is longer than the specified 100
# Created a chunk of size 1428, which is longer than the specified 100
# Created a chunk of size 557, which is longer than the specified 100
# Created a chunk of size 441, which is longer than the specified 100
# Created a chunk of size 211, which is longer than the specified 100
# Created a chunk of size 732, which is longer than the specified 100

# %%
print(chunked_data[2])
# Out:
# page_content='Light
#
# Dark
# From Wikipedia, the free encyclopedia
# Part of a series on
# Artificial intelligence (AI)' metadata={'source': '/Users/balmukundmishra/Desktop/Learn-Fine-tune-deploy-LLM-Langchain/langchain/1.data-ingestion/data1.txt'}
